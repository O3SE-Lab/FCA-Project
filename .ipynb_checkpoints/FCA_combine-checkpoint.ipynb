# %%
import pandas as pd
import numpy as np

def InputContext(fileName):

    data = pd.read_csv(fileName)
    
    G = list(data.index)
    M = list(data.columns)
    I = []
    
    for i in G:
        for j in M:
            if data[j][i] == "X":
                I.append((i,j))
    K = [G,M,I]
    array = data.values
    return K

# %%
 def CA(A):
      #m들을 집어넣을 리스트
      M = []

      #전역변수 K에서 I를 가져옴
      I = K[2]

      #A_Prime 리스트
      A_Prime = []

      for a in A:
        #임시적으로 저장할 리스트
        temp = []

        #I에서 A의 요소들의 속성들을 가져와 M에 저장
        for i in I:
          if i[0] == a:
            temp.append(i[1])
        M.append(temp)

      if len(M) != 0: #공집합일 경우를 제외

        #M에서 비교하여 공통적인 m들을 구함
        for m in M[0]:
          is_in = False  #모두 포함하는지 확인할 boolean
          for i in range(len(M)):
            if m in M[i]:
              if i == (len(M)-1):  #마지막까지 포함하면 is_in을 True로 바꿈
                is_in = True
              continue

            #없는경우 에는 루프를 끊음
            else:
              break

          #is_in이 True일경우 A_Prime에 넣음
          if is_in:
            A_Prime.append(m)

      return A_Prime

def CO(B):
  #g들을 집어넣을 리스트
  G = []

  #전역변수 K에서 I를 가져옴
  I = K[2]

  #B_Prime 리스트
  B_Prime = []

  for b in B:
    #임시적으로 저장할 리스트
    temp = []

    #I에서 B의 요소들의 속성들을 가져와 G에 저장
    for i in I:
      if i[1] == b:
        temp.append(i[0])
    G.append(temp)

  if len(G) != 0: #공집합일 경우를 제외

    #G에서 비교하여 공통적인 g들을 구함
    for g in G[0]:
      is_in = False  #모두 포함하는지 확인할 boolean
      for i in range(len(G)):
        if g in G[i]:
          if i == (len(G)-1):  #마지막까지 포함하면 is_in을 True로 바꿈
            is_in = True
          continue

        #없는경우 에는 루프를 끊음
        else:
          break

      #is_in이 True일경우 B_Prime에 넣음 
      if is_in:
        B_Prime.append(g)

  return B_Prime

# %%
def powerset(List):
    

def extractConcepts():
    FC_set = [] #FC들을 저장할 함수
    A = list(powerset(K[0])) #객채들의 부분집합
    B = list(powerset(K[1])) #속성들의 부분집합
    for a in A: #A안의 a와 B안의 b를 서로 비교하여 조건이 맞다면 FC_set에 집어넣음
        for b in B:
            if CA(a) == b:
                if CO(b) == a:
                    FC_set.append([a, b])
                    break #넣은 뒤 루프를 끊고 다음루프로 넘어감
    return FC_set

# %%
csv_FileName = "./TestData.csv"
K = InputContext(csv_FileName)
# A = ["Air Canada", "Air New Zealand", "Scandinavian Airlines"]
# B = ["Latin America", "Europe", "United States"]

# A_Prime = CA(A)
# B_Prime = CO(B)

# print(A_Prime)
# print(B_Prime)
# Out:
# [(), ('Air Canada',), ('Air New Zealand',), ('All Nippon Airways',), ('Ansett Australia',), ('The Austian Airlines Group',), ('British Midland',), ('Lufthansa',), ('Mexicana',), ('Scandinavian Airlines',), ('Singapore Airlines',), ('Thai Airways International',), ('United Airlines',), ('VARIG',), ('Air Canada', 'Air New Zealand'), ('Air Canada', 'All Nippon Airways'), ('Air Canada', 'Ansett Australia'), ('Air Canada', 'The Austian Airlines Group'), ('Air Canada', 'British Midland'), ('Air Canada', 'Lufthansa'), ('Air Canada', 'Mexicana'), ('Air Canada', 'Scandinavian Airlines'), ('Air Canada', 'Singapore Airlines'), ('Air Canada', 'Thai Airways International'), ('Air Canada', 'United Airlines'), ('Air Canada', 'VARIG'), ('Air New Zealand', 'All Nippon Airways'), ('Air New Zealand', 'Ansett Australia'), ('Air New Zealand', 'The Austian Airlines Group'), ('Air New Zealand', 'British Midland'), ('Air New Zealand', 'Lufthansa'), ('Air New Zealand', 'Mexicana'), ('Air New Zealand', 'Scandinavian Airlines'), ('Air New Zealand', 'Singapore Airlines'), ('Air New Zealand', 'Thai Airways International'), ('Air New Zealand', 'United Airlines'), ('Air New Zealand', 'VARIG'), ('All Nippon Airways', 'Ansett Australia'), ('All Nippon Airways', 'The Austian Airlines Group'), ('All Nippon Airways', 'British Midland'), ('All Nippon Airways', 'Lufthansa'), ('All Nippon Airways', 'Mexicana'), ('All Nippon Airways', 'Scandinavian Airlines'), ('All Nippon Airways', 'Singapore Airlines'), ('All Nippon Airways', 'Thai Airways International'), ('All Nippon Airways', 'United Airlines'), ('All Nippon Airways', 'VARIG'), ('Ansett Australia', 'The Austian Airlines Group'), ('Ansett Australia', 'British Midland'), ('Ansett Australia', 'Lufthansa'), ('Ansett Australia', 'Mexicana'), ('Ansett Australia', 'Scandinavian Airlines'), ('Ansett Australia', 'Singapore Airlines'), ('Ansett Australia', 'Thai Airways International'), ('Ansett Australia', 'United Airlines'), ('Ansett Australia', 'VARIG'), ('The Austian Airlines Group', 'British Midland'), ('The Austian Airlines Group', 'Lufthansa'), ('The Austian Airlines Group', 'Mexicana'), ('The Austian Airlines Group', 'Scandinavian Airlines'), ('The Austian Airlines Group', 'Singapore Airlines'), ('The Austian Airlines Group', 'Thai Airways International'), ('The Austian Airlines Group', 'United Airlines'), ('The Austian Airlines Group', 'VARIG'), ('British Midland', 'Lufthansa'), ('British Midland', 'Mexicana'), ('British Midland', 'Scandinavian Airlines'), ('British Midland', 'Singapore Airlines'), ('British Midland', 'Thai Airways International'), ('British Midland', 'United Airlines'), ('British Midland', 'VARIG'), ('Lufthansa', 'Mexicana'), ('Lufthansa', 'Scandinavian Airlines'), ('Lufthansa', 'Singapore Airlines'), ('Lufthansa', 'Thai Airways International'), ('Lufthansa', 'United Airlines'), ('Lufthansa', 'VARIG'), ('Mexicana', 'Scandinavian Airlines'), ('Mexicana', 'Singapore Airlines'), ('Mexicana', 'Thai Airways International'), ('Mexicana', 'United Airlines'), ('Mexicana', 'VARIG'), ('Scandinavian Airlines', 'Singapore Airlines'), ('Scandinavian Airlines', 'Thai Airways International'), ('Scandinavian Airlines', 'United Airlines'), ('Scandinavian Airlines', 'VARIG'), ('Singapore Airlines', 'Thai Airways International'), ('Singapore Airlines', 'United Airlines'), ('Singapore Airlines', 'VARIG'), ('Thai Airways International', 'United Airlines'), ('Thai Airways International', 'VARIG'), ('United Airlines', 'VARIG'), ('Air Canada', 'Air New Zealand', 'All Nippon Airways'), ('Air Canada', 'Air New Zealand', 'Ansett Australia'), ('Air Canada', 'Air New Zealand', 'The Austian Airlines Group'), ('Air Canada', 'Air New Zealand', 'British Midland'), ('Air Canada', 'Air New Zealand', 'Lufthansa'), ('Air Canada', 'Air New Zealand', 'Mexicana'), ('Air Canada', 'Air New Zealand', 'Scandinavian Airlines'), ('Air Canada', 'Air New Zealand', 'Singapore Airlines'), ('Air Canada', 'Air New Zealand', 'Thai Airways Interna ...
# [(), ('Latin America',), ('Europe',), ('Canada',), ('Asia Pacific',), ('Middle East',), ('Africa',), ('Mexico',), ('Canribbean',), ('United States',), ('Latin America', 'Europe'), ('Latin America', 'Canada'), ('Latin America', 'Asia Pacific'), ('Latin America', 'Middle East'), ('Latin America', 'Africa'), ('Latin America', 'Mexico'), ('Latin America', 'Canribbean'), ('Latin America', 'United States'), ('Europe', 'Canada'), ('Europe', 'Asia Pacific'), ('Europe', 'Middle East'), ('Europe', 'Africa'), ('Europe', 'Mexico'), ('Europe', 'Canribbean'), ('Europe', 'United States'), ('Canada', 'Asia Pacific'), ('Canada', 'Middle East'), ('Canada', 'Africa'), ('Canada', 'Mexico'), ('Canada', 'Canribbean'), ('Canada', 'United States'), ('Asia Pacific', 'Middle East'), ('Asia Pacific', 'Africa'), ('Asia Pacific', 'Mexico'), ('Asia Pacific', 'Canribbean'), ('Asia Pacific', 'United States'), ('Middle East', 'Africa'), ('Middle East', 'Mexico'), ('Middle East', 'Canribbean'), ('Middle East', 'United States'), ('Africa', 'Mexico'), ('Africa', 'Canribbean'), ('Africa', 'United States'), ('Mexico', 'Canribbean'), ('Mexico', 'United States'), ('Canribbean', 'United States'), ('Latin America', 'Europe', 'Canada'), ('Latin America', 'Europe', 'Asia Pacific'), ('Latin America', 'Europe', 'Middle East'), ('Latin America', 'Europe', 'Africa'), ('Latin America', 'Europe', 'Mexico'), ('Latin America', 'Europe', 'Canribbean'), ('Latin America', 'Europe', 'United States'), ('Latin America', 'Canada', 'Asia Pacific'), ('Latin America', 'Canada', 'Middle East'), ('Latin America', 'Canada', 'Africa'), ('Latin America', 'Canada', 'Mexico'), ('Latin America', 'Canada', 'Canribbean'), ('Latin America', 'Canada', 'United States'), ('Latin America', 'Asia Pacific', 'Middle East'), ('Latin America', 'Asia Pacific', 'Africa'), ('Latin America', 'Asia Pacific', 'Mexico'), ('Latin America', 'Asia Pacific', 'Canribbean'), ('Latin America', 'Asia Pacific', 'United States'), ('Latin America', 'Middle East', 'Africa'), ('Latin America', 'Middle East', 'Mexico'), ('Latin America', 'Middle East', 'Canribbean'), ('Latin America', 'Middle East', 'United States'), ('Latin America', 'Africa', 'Mexico'), ('Latin America', 'Africa', 'Canribbean'), ('Latin America', 'Africa', 'United States'), ('Latin America', 'Mexico', 'Canribbean'), ('Latin America', 'Mexico', 'United States'), ('Latin America', 'Canribbean', 'United States'), ('Europe', 'Canada', 'Asia Pacific'), ('Europe', 'Canada', 'Middle East'), ('Europe', 'Canada', 'Africa'), ('Europe', 'Canada', 'Mexico'), ('Europe', 'Canada', 'Canribbean'), ('Europe', 'Canada', 'United States'), ('Europe', 'Asia Pacific', 'Middle East'), ('Europe', 'Asia Pacific', 'Africa'), ('Europe', 'Asia Pacific', 'Mexico'), ('Europe', 'Asia Pacific', 'Canribbean'), ('Europe', 'Asia Pacific', 'United States'), ('Europe', 'Middle East', 'Africa'), ('Europe', 'Middle East', 'Mexico'), ('Europe', 'Middle East', 'Canribbean'), ('Europe', 'Middle East', 'United States'), ('Europe', 'Africa', 'Mexico'), ('Europe', 'Africa', 'Canribbean'), ('Europe', 'Africa', 'United States'), ('Europe', 'Mexico', 'Canribbean'), ('Europe', 'Mexico', 'United States'), ('Europe', 'Canribbean', 'United States'), ('Canada', 'Asia Pacific', 'Middle East'), ('Canada', 'Asia Pacific', 'Africa'), ('Canada', 'Asia Pacific', 'Mexico'), ('Canada', 'Asia Pacific', 'Canribbean'), ('Canada', 'Asia Pacific', 'United States'), ('Canada', 'Middle East', 'Africa'), ('Canada', 'Middle East', 'Mexico'), ('Canada', 'Middle East', 'Canribbean'), ('Canada', 'Middle East', 'United States'), ('Canada', 'Africa', 'Mexico'), ('Canada', 'Africa', 'Canribbean'), ('Canada', 'Africa', 'United States'), ('Canada', 'Mexico', 'Canribbean'), ('Canada', 'Mexico', 'United States'), ('Canada', 'Canribbean', 'United States'), ('Asia Pacific', 'Middle East', 'Africa'), ('Asia Pacific', 'Middle East', 'Mexico'), ('Asia Pacific', 'Middle East', 'Canribbean'), ('Asia Pacific', 'Middle East', 'United States'), (' ...
# []
